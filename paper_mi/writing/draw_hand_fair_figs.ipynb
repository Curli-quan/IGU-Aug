# %%
# %matplotlib inline
import matplotlib.pylab as plt
# plt.style.use('ggplot')
import seaborn as sns
import pandas as pd
import numpy as np

x = [1,2,3,4]
x = np.array(x)
y = [[61.60418,	70.65388,77.7062,85.7927],
     [61.50,	70.38,	76.4,	84.86],
     [71.58,	78.89,	84.19,	90.33],
     [71.48,	79.06,	83.89,	90.37],]
x2= ["male", "female", "male (ours)", "female (ours)"]

plt.figure(figsize=(6, 4)) 
sns.set_style("whitegrid")
for i in range(2):
    sns.lineplot(x=x, y=y[i], label=f"{x2[i]}", color=sns.color_palette()[i])
    sns.scatterplot(x=x, y=y[i])

for i in range(2):
    i += 2
    sns.lineplot(x=x, y=y[i], label=f"{x2[i]}", color=sns.color_palette()[i-2], linestyle='--')
    sns.scatterplot(x=x, y=y[i])

# for i in range(3):
#     sns.lineplot(x=x, y=y[i])
#     sns.scatterplot(x=x, y=y[i], label=i)

# plt.xlabel(r"SDR()")
plt.xticks(np.arange(1,5), ['SDR 2', 'SDR 2.5', 'SDR 3', 'SDR 4' ])
plt.ylabel("%")
sns.despine(left=True)
plt.grid(False, axis='x')
plt.tight_layout()
plt.savefig("hand_fair.pdf")
