# %%
# %matplotlib inline
import matplotlib.pylab as plt
import seaborn as sns
import pandas as pd
import numpy as np
from einops  import rearrange
plt.style.use('ggplot')

fig = plt.figure()
# sns.set(rc={"figure.figsize":(5.1, 4)}) 
pth = "/home1/quanquan/datasets/Cephalometric/entr1/train/1.npy"
data = np.load(pth)
data = rearrange(data, "h w -> (h w)")
print(data.shape)
data = pd.DataFrame({"Mutual Information (MI)": data})
sns.displot(data, x="Mutual Information (MI)" , height=4, aspect=1.8)
plt.savefig("entr_dist.pdf")
# Out:
# (147456,)
