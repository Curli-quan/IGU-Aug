# %% [markdown]
# ### Estimate necessary MI

# %%
# import os
# os.chdir("..")

# %%
import numpy as np

data = np.load("../cache/res_total_lm.npy")
print(data.mean(), data.std(), data.max())
print( data.mean()/ data.max(), (data.mean() - data.std())/data.max()) # 0.44, 0.32
# Out:
# 1.557879398114505 0.4429374350131507 3.478368118468378
# 0.447876517106672 0.3205359309676211

# %%
# %matplotlib inline
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use("ggplot")
fig = plt.figure(figsize=(8,4))
sns.kdeplot(data, shade=True)
plt.xlabel("Mutual Information (MI)")
plt.savefig("entr_dist.pdf")
# plt.ylabel("Percentage (%)")
