# %%
# %matplotlib inline
import matplotlib.pylab as plt
plt.style.use('ggplot')
import seaborn as sns
import pandas as pd
import numpy as np

x = [0.8,1.0,1.2,1.4]
x = np.array(x)
y = [[2.42,2.411 ,2.402,2.409],
     [2.38,2.351,2.37,2.38],
     [2.382,2.345,2.354,2.37],
     [2.41,2.364,2.38,2.405],]
x2= [0.8,1.0,1.2,1.4]

plt.figure(figsize=(6, 4)) 
data = pd.read_csv("../mi_vs_aug2.csv")
# sns.lineplot(data=data, x='contrast', y='mi')
for i in range(4):
    sns.lineplot(x=x, y=y[i])
    sns.scatterplot(x=x, y=y[i], label=f"$\lambda^h$ = {x2[i]}")

# for i in range(3):
#     sns.lineplot(x=x, y=y[i])
#     sns.scatterplot(x=x, y=y[i], label=i)

plt.xlabel(r"$\lambda^m$")
plt.ylabel("MRE")
plt.tight_layout()
plt.savefig("mre_eta.pdf")

# %%
# %matplotlib inline
import matplotlib.pylab as plt
plt.style.use('ggplot')
import seaborn as sns
import pandas as pd
import numpy as np

x = [-0.1,0.,0.1,0.2]
x = np.array(x)
y = [[2.42,2.41 ,2.40,2.40],
     [2.38,2.35,2.37,2.38],
     [2.38,2.33,2.35,2.37]]
x2= [-0.1,0,0.1]

plt.figure(figsize=(6, 4)) 
data = pd.read_csv("../mi_vs_aug2.csv")
# sns.lineplot(data=data, x='contrast', y='mi')
for i in range(3):
    sns.lineplot(x=x, y=y[i])
    sns.scatterplot(x=x, y=y[i], label=f"$\eta^h$ = {x2[i]}")


plt.xlabel(r"$\eta^m$")
plt.ylabel("MRE")
plt.tight_layout()
plt.savefig("mre_eta_hand.pdf")
