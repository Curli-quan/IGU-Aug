# %%
import glob
pathdir = '/home1/quanquan/datasets/Cephalometric/TmpImage/TrainingData/*.bmp'
paths = glob.glob(pathdir)
# print(paths)

# %%
# %matplotlib inline
import cv2
import matplotlib.pylab as plt

img = cv2.imread(paths[1])
img = cv2.resize(img, (256,256))
plt.imshow(img)
cv2.imwrite("tmp_002.png", img)
# Out:
# True
