# %%
# %matplotlib inline
import matplotlib.pylab as plt
import cv2

img = cv2.imread("/home1/quanquan/datasets/Cephalometric/RawImage/TrainingData/150.bmp")
plt.imshow(img)

# %%
img = cv2.imread("/home1/quanquan/datasets/Cephalometric/RawImage/NoisyTrainingData/150.bmp")
plt.imshow(img)
